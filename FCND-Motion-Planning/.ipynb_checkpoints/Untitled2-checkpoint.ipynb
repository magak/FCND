# %%
import argparse
import time
import msgpack
import os.path
from enum import Enum, auto

import numpy as np
import math
import pickle

import matplotlib.pyplot as plt


from planning_utils import a_star, heuristic, create_grid, prune_path, create_grid_and_edges, a_starGraph, GetGraph, closest_point, GetGridAndOffsets, GetLat0Lon0, GetVoronoyGraph
from udacidrone import Drone
from udacidrone.connection import MavlinkConnection
from udacidrone.messaging import MsgID
from udacidrone.frame_utils import global_to_local, local_to_global

TARGET_ALTITUDE = 5
SAFETY_DISTANCE = 5

# %%
data = np.loadtxt('colliders.csv', delimiter=',', dtype='Float64', skiprows=2)

# %%
print(data)
# Out:
# [[-310.2389   -439.2315     85.5         5.          5.         85.5     ]
#  [-300.2389   -439.2315     85.5         5.          5.         85.5     ]
#  [-290.2389   -439.2315     85.5         5.          5.         85.5     ]
#  ...
#  [ 257.8061    425.1645      1.75852     1.292725    1.292725    1.944791]
#  [ 293.9967    368.3391      3.557666    1.129456    1.129456    3.667319]
#  [ 281.5162    354.4156      4.999351    1.053772    1.053772    4.950246]]

# %%
grid, north_offset, east_offset = create_grid(data, TARGET_ALTITUDE, SAFETY_DISTANCE)

# %%
fig = plt.figure()

plt.imshow(grid, cmap='Greys', origin='lower')


plt.xlabel('EAST')
plt.ylabel('NORTH')

plt.show()

# %%
with open('colliders.csv', "r") as f:
    firstline = f.readline().split(',')

lat0 = float(firstline[0].split()[1])
lon0 = float(firstline[1].split()[1])

print(lat0)
print(lon0)
# Out:
# 37.79248
# -122.39745

# %%
class States(Enum):
    MANUAL = auto()
    ARMING = auto()
    TAKEOFF = auto()
    WAYPOINT = auto()
    LANDING = auto()
    DISARMING = auto()
    PLANNING = auto()

class MotionPlanning(Drone):

    def __init__(self, connection):
        super().__init__(connection)

        self.target_position = np.array([0.0, 0.0, 0.0])
        self.waypoints = []
        self.in_mission = True
        self.check_state = {}

        # initial state
        self.flight_state = States.MANUAL

        # register all your callbacks here
        self.register_callback(MsgID.LOCAL_POSITION, self.local_position_callback)
        self.register_callback(MsgID.LOCAL_VELOCITY, self.velocity_callback)
        self.register_callback(MsgID.STATE, self.state_callback)

    def local_position_callback(self):
        if self.flight_state == States.TAKEOFF:
            if -1.0 * self.local_position[2] > 0.95 * self.target_position[2]:
                self.waypoint_transition()
        elif self.flight_state == States.WAYPOINT:
            if np.linalg.norm(self.target_position[0:2] - self.local_position[0:2]) < self.get_waypoint_transition_threshold():
                if len(self.waypoints) > 0:
                    self.waypoint_transition()
                else:
                    if np.linalg.norm(self.local_velocity[0:2]) < 1.0:
                        self.landing_transition()
                        
    def get_waypoint_transition_threshold(self):
        result = 1.0
        
        if len(self.waypoints) > 2:        
            velocity = np.linalg.norm(self.local_velocity[0:2])        
            result = 2.5*math.exp(-1/np.clip(velocity, 1, 10))
        
        print('threshold={}'.format(result))
        return result

    def velocity_callback(self):
        if self.flight_state == States.LANDING:
            if self.global_position[2] - self.global_home[2] < 0.1:
                if abs(self.local_position[2]) < 0.01:
                    self.disarming_transition()

    def state_callback(self):
        if self.in_mission:
            if self.flight_state == States.MANUAL:
                self.arming_transition()
            elif self.flight_state == States.ARMING:
                if self.armed:
                    self.plan_path()
            elif self.flight_state == States.PLANNING:
                self.takeoff_transition()
            elif self.flight_state == States.DISARMING:
                if ~self.armed & ~self.guided:
                    self.manual_transition()

    def arming_transition(self):
        self.flight_state = States.ARMING
        print("arming transition")
        self.arm()
        self.take_control()

    def takeoff_transition(self):
        self.flight_state = States.TAKEOFF
        print("takeoff transition")
        self.takeoff(self.target_position[2])

    def waypoint_transition(self):
        self.flight_state = States.WAYPOINT
        print("waypoint transition")
        if(self.waypoints):
            self.target_position = self.waypoints.pop(0)
        else:
            self.landing_transition()
            return
            
        print('target position', self.target_position)
        self.cmd_position(self.target_position[0], self.target_position[1], self.target_position[2], self.target_position[3])

    def landing_transition(self):
        self.flight_state = States.LANDING
        print("landing transition")
        self.land()

    def disarming_transition(self):
        self.flight_state = States.DISARMING
        print("disarm transition")
        self.disarm()
        self.release_control()

    def manual_transition(self):
        self.flight_state = States.MANUAL
        print("manual transition")
        self.stop()
        self.in_mission = False

    def send_waypoints(self):
        print("Sending waypoints to simulator ...")
        data = msgpack.dumps(self.waypoints)
        self.connection._master.write(data)

    def plan_path(self):
        self.flight_state = States.PLANNING
        print("Searching for a path ...")
        TARGET_ALTITUDE = 10
        SAFETY_DISTANCE = 5

        self.target_position[2] = TARGET_ALTITUDE
        
        # TODO: read lat0, lon0 from colliders into floating point values
        lat0, lon0 = GetLat0Lon0()
        
        # TODO: set home position to (lon0, lat0, 0)
        self.set_home_position(lon0, lat0, 0)

        # TODO: retrieve current global position
        global_position = self.global_position
 
        # TODO: convert to current local position using global_to_local()        
        local_position = global_to_local(global_position, self.global_home)
        
        print('global home {0}, position {1}, local position {2}'.format(self.global_home, self.global_position,
                                                                         self.local_position))        
        
        grid, north_offset, east_offset = GetGridAndOffsets()
        graph = GetVoronoyGraph()
        
        # Define starting point on the grid (this is just grid center)
        # grid_start = (-north_offset, -east_offset)
        # TODO: convert start position to current position rather than map center
        start = (int(local_position[0]-north_offset), int(local_position[1])-east_offset)
        #print("start={0}, north_offset={1}, east_offset={2}".format(start, north_offset, east_offset))
        
        # Set goal as some arbitrary position on the grid        
        goal = (250,720)# (-north_offset + 10, -east_offset + 10)
                
        
        # TODO: adapt to set goal as latitude / longitude position and convert
        goal_position = global_to_local([-122.397450, 37.792480, 0.0], self.global_home)
        goal = (int(goal_position[0])-north_offset, int(goal_position[1])-east_offset)        
        #goal = (500,15)# (-north_offset + 10, -east_offset + 10)

        # Run A* to find a path from start to goal
        # TODO: add diagonal motions with a cost of sqrt(2) to your A* implementation
        # or move to a different search space such as a graph (not done here)        
        
        waypointsPath = self.GetPath(grid, graph, start, goal)
        if(waypointsPath is None):
            print("Path was not found")
            waypointsPath = []
              
        self.waypoints = waypointsPath
        print(self.waypoints)
        self.send_waypoints()

    def GetPath(self, grid, graph, start, goal):
        
        if(grid[goal[0], goal[1]] == 1):
            print("Goal is unreachable")
            return None
        
        start_g = closest_point(graph, start)
        goal_g = closest_point(graph, goal)
        print(goal_g)
        
        path, _ = a_starGraph(graph, heuristic, start_g, goal_g)
        # If it is not possible to find a path in graph, let's find a path in the grid
        if(path is None):
            print('Searching in grid')
            newpath, _ = a_star(grid, heuristic, start, goal)
            newpath = prune_path(newpath)
        else:            
            start_g = (int(start_g[0]), int(start_g[1]))
            goal_g = (int(goal_g[0]), int(goal_g[1]))
        
            print('start={0}, start_g={1}'.format(start, start_g))
            pathToBegin, _ = a_star(grid, heuristic, start, start_g)
            pathFromEnd, _ = a_star(grid, heuristic, goal_g, goal)
        
            if(pathToBegin is None or pathFromEnd is None):
                return None
        
            newpath = pathToBegin + path + pathFromEnd
            newpath = prune_path(newpath)
        
        return [[int(p[0]) + north_offset, int(p[1]) + east_offset, TARGET_ALTITUDE, 0] for p in newpath]
    
    def start(self):
        self.start_log("Logs", "NavLog.txt")

        print("starting connection")
        self.connection.start()

        self.stop_log()

conn = MavlinkConnection('tcp:{0}:{1}'.format('127.0.0.1', 5760), timeout=60)
drone = MotionPlanning(conn)
time.sleep(1)

drone.start()
# Out:
# Logs\TLog.txt
# Logs\NavLog.txt
# starting connection
# arming transition
# Searching for a path ...
# global home [-122.3974533   37.7924804    0.       ], position [-122.4022874   37.7941314    0.13     ], local position [ 1.8344455e+02 -4.2970166e+02 -1.3077727e-01]
# (315.76114, 445.76846)
# Found a path.
# start=(496, 19), start_g=(490, 17)
# Found a path.
# Found a path.
# [[180, -426, 5, 0], [178, -426, 5, 0], [177, -427, 5, 0], [176, -427, 5, 0], [175, -428, 5, 0], [174, -428, 5, 0], [174, -428, 5, 0], [149, -420, 5, 0], [127, -420, 5, 0], [124, -418, 5, 0], [114, -415, 5, 0], [104, -415, 5, 0], [86, -409, 5, 0], [89, -395, 5, 0], [89, -355, 5, 0], [93, -339, 5, 0], [92, -335, 5, 0], [94, -325, 5, 0], [94, -295, 5, 0], [97, -282, 5, 0], [102, -277, 5, 0], [103, -273, 5, 0], [107, -265, 5, 0], [109, -255, 5, 0], [109, -217, 5, 0], [119, -202, 5, 0], [119, -150, 5, 0], [122, -147, 5, 0], [124, -135, 5, 0], [124, -115, 5, 0], [122, -105, 5, 0], [117, -92, 5, 0], [116, -85, 5, 0], [129, -65, 5, 0], [129, -65, 5, 0], [129, -40, 5, 0], [104, -25, 5, 0], [98, -18, 5, 0], [94, -17, 5, 0], [93, -16, 5, 0], [84, -12, 5, 0], [64, -7, 5, 0], [54, -2, 5, 0], [44, 5, 5, 0], [34, 15, 5, 0], [32, 17, 5, 0], [26, 14, 5, 0], [7, 0, 5, 0], [-1, 0, 5, 0], [-1, 0, 5, 0], [0, 0, 5, 0]]
# Sending waypoints to simulator ...
# takeoff transition
# waypoint transition
# target position [180, -426, 5, 0]
# threshold=1.103638323514327
# threshold=1.103638323514327
# threshold=1.103638323514327
# threshold=1.2685640137914114
# threshold=1.9399415975851606
# threshold=2.3807455873859826
# threshold=2.430888879688506
# waypoint transition
# target position [178, -426, 5, 0]
# threshold=2.3929737349170406
# threshold=2.3725106089559693
# waypoint transition
# target position [177, -427, 5, 0]
# threshold=2.2446344437892356
# waypoint transition
# target position [176, -427, 5, 0]
# threshold=2.3264504190560262
# waypoint transition
# target position [175, -428, 5, 0]
# threshold=2.3552330036375015
# threshold=2.3490554934092813
# waypoint transition
# target position [174, -428, 5, 0]
# threshold=2.237295088417447
# waypoint transition
# target position [174, -428, 5, 0]
# threshold=2.057606957165486
# waypoint transition
# target position [149, -420, 5, 0]
# threshold=2.05939453559502
# threshold=1.941136908138772
# threshold=2.221835488623634
# threshold=2.379778205304437
# threshold=2.4828369762034272
# threshold=2.6061628949258977
# threshold=2.6062786659964288
# threshold=2.644721312480852
# threshold=2.668517548572943
# threshold=2.6781239618030157
# threshold=2.6782000952645744
# threshold=2.6791333721884687
# threshold=2.6800490148265013
# threshold=2.6798096317521085
# threshold=2.623704549426415
# waypoint transition
# target position [127, -420, 5, 0]
# threshold=2.5589757177871393
# threshold=2.606402754739465
# threshold=2.64031756868241
# threshold=2.663677187235778
# threshold=2.6736520298480704
# threshold=2.6770397289137886
# threshold=2.6782180836561102
# threshold=2.679411632284398
# threshold=2.679731000971593
# threshold=2.672950546169505
# threshold=2.6128093099251375
# waypoint transition
# target position [124, -418, 5, 0]
# threshold=2.5127521525949392
# threshold=2.494002794798893
# waypoint transition
# target position [114, -415, 5, 0]
# threshold=2.463842732505444
# threshold=2.5469730119677534
# threshold=2.610562537315183
# threshold=2.6504034285111104
# threshold=2.6668617519667865
# threshold=2.625122254037567
# waypoint transition
# target position [104, -415, 5, 0]
# threshold=2.5488544045732766
# threshold=2.590311854276497
# threshold=2.6201060860932
# threshold=2.640763046751916
# threshold=2.646560860732306
# threshold=2.570826641626345
# waypoint transition
# target position [86, -409, 5, 0]
# threshold=2.4858800815761732
# threshold=2.547513416029008
# threshold=2.588508777186056
# threshold=2.622088646004393
# threshold=2.6508047544938265
# threshold=2.668843476907827
# threshold=2.6750654906578895
# threshold=2.678390259383193
# threshold=2.6740987027233123
# threshold=2.6051359891354764
# waypoint transition
# target position [89, -395, 5, 0]
# threshold=2.511699472038626
# threshold=2.46567684553708
# threshold=2.4660707938280826
# threshold=2.4485267266107558
# threshold=2.4761986966870833
# threshold=2.5093593389659956
# threshold=2.5492284626603605
# threshold=2.5837527168108094
# threshold=2.615259066520244
# threshold=2.638970075282275
# threshold=2.6100604587243543
# waypoint transition
# target position [89, -355, 5, 0]
# threshold=2.54992992291207
# threshold=2.5466693140093843
# threshold=2.5663176135267016
# threshold=2.596616558517332
# threshold=2.624476510110628
# threshold=2.6559885667254255
# threshold=2.669705520165934
# threshold=2.676725766243953
# threshold=2.6790478289793214
# threshold=2.679526632120689
# threshold=2.680231455542761
# threshold=2.6798914761056807
# threshold=2.6805707163155916
# threshold=2.680231455542761
# threshold=2.680695912703052
# threshold=2.6808028320032635
# threshold=2.6797036205284446
# threshold=2.6799159207188175
# threshold=2.6742293753196895
# threshold=2.620969987099393
# waypoint transition
# target position [93, -339, 5, 0]
# threshold=2.580568901361165
# threshold=2.613248413449475
# threshold=2.6475553256157847
# threshold=2.6476068588855632
# threshold=2.6684043994706945
# threshold=2.6756691062016364
# threshold=2.679157412604936
# threshold=2.6381396061959004
# waypoint transition
# target position [92, -335, 5, 0]
# threshold=2.585935447513897
# threshold=2.5695479750265173
# waypoint transition
# target position [94, -325, 5, 0]
# threshold=2.554363750857203
# threshold=2.6022330938061065
# threshold=2.640370081897799
# threshold=2.6405337349804943
# threshold=2.6642328363455725
# threshold=2.5998309455730615
# waypoint transition
# target position [94, -295, 5, 0]
# threshold=2.60031605161514
# threshold=2.6094346598624827
# threshold=2.6463299650730514
# threshold=2.668138420293124
# threshold=2.676009384084562
# threshold=2.6794719504452695
# threshold=2.6801592854518472
# threshold=2.680841944754352
# threshold=2.681180753172168
# threshold=2.6811839855017565
# threshold=2.680517725510235
# threshold=2.6805133243435524
# threshold=2.679124646482109
# threshold=2.6420625881295763
# waypoint transition
# target position [97, -282, 5, 0]
# threshold=2.6079622695490916
# threshold=2.641490606543287
# threshold=2.664096194817458
# threshold=2.6735292342739174
# threshold=2.676963552401059
# threshold=2.6654547864243034
# threshold=2.6006336992505448
# waypoint transition
# target position [102, -277, 5, 0]
# threshold=2.5404183884786264
# threshold=2.567880267454736
# threshold=2.592431483952657
# threshold=2.568666893717066
# waypoint transition
# target position [103, -273, 5, 0]
# threshold=2.535258260555283
# threshold=2.5359746639879788
# waypoint transition
# target position [107, -265, 5, 0]
# threshold=2.5295572121277217
# threshold=2.5888607331953017
# threshold=2.6356938726508368
# threshold=2.6622064770308067
# threshold=2.6492650298252878
# waypoint transition
# target position [109, -255, 5, 0]
# threshold=2.619200417195514
# threshold=2.653362616359057
# threshold=2.668678282791875
# threshold=2.67527807168276
# threshold=2.659042654403324
# waypoint transition
# target position [109, -217, 5, 0]
# threshold=2.6591081976422766
# threshold=2.623985624678081
# threshold=2.6524634184921685
# threshold=2.670379625506671
# threshold=2.6794671185375916
# threshold=2.680829926297204
# threshold=2.680493229706696
# threshold=2.6815160009389043
# threshold=2.680841944754352
# threshold=2.6815114521288974
# threshold=2.6804949522554993
# threshold=2.6791341477717134
# threshold=2.679815796377109
# threshold=2.6804970575543816
# threshold=2.6791403522314
# threshold=2.6801775246162354
# threshold=2.6756931475244374
# threshold=2.6159949201038057
# waypoint transition
# target position [119, -202, 5, 0]
# threshold=2.5526847781945623
# threshold=2.5710284642818246
# threshold=2.5960543628665294
# threshold=2.6270481578094955
# threshold=2.6509764275473873
# threshold=2.670327191457597
# threshold=2.6704954389950593
# threshold=2.67642678503606
# threshold=2.658250476749262
# waypoint transition
# target position [119, -150, 5, 0]
# threshold=2.6022469480002823
# threshold=2.60254565900669
# threshold=2.592646392848054
# threshold=2.6027171106897944
# threshold=2.62245769283813
# threshold=2.647690388948753
# threshold=2.6666815336980285
# threshold=2.6757171833999918
# threshold=2.677555686553027
# threshold=2.680148148398955
# threshold=2.679807512578481
# threshold=2.6801322088303783
# threshold=2.680811418983997
# threshold=2.680811418983997
# threshold=2.680148148398955
# threshold=2.68016446953772
# threshold=2.680860065209631
# threshold=2.6801982558056463
# threshold=2.680860065209631
# threshold=2.681198434691801
# threshold=2.67994921010905
# threshold=2.6810886848103594
# threshold=2.6811999555427564
# threshold=2.6780176066288672
# threshold=2.6362305803462056
# waypoint transition
# target position [122, -147, 5, 0]
# threshold=2.5705671993928205
# threshold=2.5406687198419298
# threshold=2.4809877077846316
# waypoint transition
# target position [124, -135, 5, 0]
# threshold=2.464200606543845
# threshold=2.534497128878826
# threshold=2.5868069909199263
# threshold=2.6286475013732047
# threshold=2.6584963935616552
# threshold=2.658526420754625
# threshold=2.585109811886166
# waypoint transition
# target position [124, -115, 5, 0]
# threshold=2.539999647567034
# threshold=2.5919066614853357
# threshold=2.6365609267212733
# threshold=2.664799649441591
# threshold=2.6746706061115004
# threshold=2.678318960819265
# threshold=2.6794344490012847
# threshold=2.6799301614063307
# threshold=2.6687127101081667
# threshold=2.604354497726166
# waypoint transition
# target position [122, -105, 5, 0]
# threshold=2.5738458850163304
# threshold=2.620349080343642
# threshold=2.6525507658437104
# threshold=2.6676945311306737
# threshold=2.6317184946100656
# waypoint transition
# target position [117, -92, 5, 0]
# threshold=2.5984331098084974
# threshold=2.6427692060644397
# threshold=2.666469810377037
# threshold=2.6739187914131683
# threshold=2.6775877642199593
# threshold=2.675927864906396
# threshold=2.626013411849205
# waypoint transition
# target position [116, -85, 5, 0]
# threshold=2.5854524927608113
# threshold=2.6224040819893837
# threshold=2.6356684180217425
# threshold=2.5655348928228534
# waypoint transition
# target position [129, -65, 5, 0]
# threshold=2.5022524316112587
# threshold=2.5339493614098654
# threshold=2.5744236799024716
# threshold=2.6139035292912385
# threshold=2.641871152829632
# threshold=2.6422610136419347
# threshold=2.665478575884847
# threshold=2.6788924704697736
# threshold=2.6796546263934165
# threshold=2.6799011366957255
# threshold=2.679294570253153
# threshold=2.680780884288967
# waypoint transition
# target position [129, -65, 5, 0]
# threshold=2.665051341016873
# waypoint transition
# target position [129, -40, 5, 0]
# threshold=2.5805204114817224
# threshold=2.53671641021889
# threshold=2.569245489142989
# threshold=2.601065157673934
# threshold=2.6337666076695943
# threshold=2.6601063916108014
# threshold=2.6719744931326237
# threshold=2.6769397978422664
# threshold=2.6804849993595345
# threshold=2.6807306734806247
# threshold=2.6810372890401624
# threshold=2.6673226915769446
# threshold=2.591494001999126
# waypoint transition
# target position [104, -25, 5, 0]
# threshold=2.5190191759011396
# threshold=2.5198903927575786
# threshold=2.5435053489003066
# threshold=2.569871716999206
# threshold=2.6014578994298576
# threshold=2.6369865731038487
# threshold=2.6630791017468933
# threshold=2.6738690791353195
# threshold=2.6769748339461894
# threshold=2.6800568951534265
# threshold=2.680908879420082
# threshold=2.6816635400052835
# threshold=2.680366448794599
# threshold=2.680829926297204
# threshold=2.6412434046321476
# waypoint transition
# target position [98, -18, 5, 0]
# threshold=2.5840468811322994
# threshold=2.6060658801954024
# threshold=2.6267574166908245
# threshold=2.641718267669509
# threshold=2.6120898915906583
# waypoint transition
# target position [94, -17, 5, 0]
# threshold=2.5486689495645933
# threshold=2.5489067851649776
# threshold=2.4853714974978964
# waypoint transition
# target position [93, -16, 5, 0]
# threshold=2.3634488830057627
# waypoint transition
# target position [84, -12, 5, 0]
# threshold=2.3322738585137595
# threshold=2.4772277945119647
# threshold=2.54990254242876
# threshold=2.6042262450408717
# threshold=2.647114169783159
# threshold=2.6374819863218177
# waypoint transition
# target position [64, -7, 5, 0]
# threshold=2.578355305327411
# threshold=2.6259027212438926
# threshold=2.6659434123567305
# threshold=2.673128606512239
# threshold=2.676963552401059
# threshold=2.67830723588291
# threshold=2.679078097129334
# threshold=2.6797173116442834
# threshold=2.67976512010164
# threshold=2.6521332180498285
# waypoint transition
# target position [54, -2, 5, 0]
# threshold=2.5902466455980693
# threshold=2.628608676256869
# threshold=2.6623989526030116
# threshold=2.67262961863009
# threshold=2.6700405650506314
# threshold=2.6070763834748614
# waypoint transition
# target position [44, 5, 5, 0]
# threshold=2.54335884312409
# threshold=2.6044561246805724
# threshold=2.6449911101037498
# threshold=2.665935955427399
# threshold=2.6743943667942958
# threshold=2.644993487878815
# waypoint transition
# target position [34, 15, 5, 0]
# threshold=2.5974784737861967
# threshold=2.639578247696357
# threshold=2.667148658061798
# threshold=2.673414074562503
# threshold=2.67723417495935
# threshold=2.677022915446144
# threshold=2.637677041261919
# waypoint transition
# target position [32, 17, 5, 0]
# threshold=2.5769175557545583
# threshold=2.5773131816463164
# waypoint transition
# target position [26, 14, 5, 0]
# threshold=2.520478048056181
# threshold=2.417666101083709
# threshold=2.4116915362375844
# threshold=2.4292068003671643
# threshold=2.451300934203161
# threshold=2.453024878028684
# threshold=2.4149344216306035
# waypoint transition
# target position [7, 0, 5, 0]
# threshold=2.371200322392923
# threshold=2.4660708614136024
# threshold=2.466798577074557
# threshold=2.537964163575007
# threshold=2.6297467091633404
# threshold=2.6626216145530304
# threshold=2.674252119954695
# threshold=2.6744236875924874
# threshold=2.6778976078505927
# threshold=2.67940118908034
# threshold=2.680238746559672
# threshold=2.6693558313724104
# waypoint transition
# target position [-1, 0, 5, 0]
# threshold=1.0
# threshold=1.0
# threshold=1.0
# threshold=1.0
# threshold=1.0
# threshold=1.0
# waypoint transition
# target position [-1, 0, 5, 0]
# threshold=1.0
# threshold=1.0
# threshold=1.0
# threshold=1.0
# threshold=1.0
# threshold=1.0
# waypoint transition
# target position [0, 0, 5, 0]
# threshold=1.0
# threshold=1.0
# threshold=1.0
# threshold=1.0
# threshold=1.0
# landing transition
# disarm transition
# manual transition
# Closing connection ...

# %%
a = {'hello': 'world'}

with open('filename.pickle', 'wb') as handle:
    pickle.dump(a, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('filename.pickle', 'rb') as handle:
    b = pickle.load(handle)
    
print(b)

# %%
#from bresenham import bresenham

# %%
#from scipy.spatial import Voronoi

# %%
# OK this might look a little ugly but...
# need to import the latest version of networkx
# This occassionally fails, so if the next cell 
# doesn't show that you're using networkx 2.1
# please "restart and clear output" from "Kernel" menu
# above and try again.
#import sys
#!{sys.executable} -m pip install -I networkx==2.1
#import pkg_resources
#pkg_resources.require("networkx==2.1")
#import networkx as nx

# %%
if os.path.isfile("Untitled1.ipynb") and os.path.isfile("setup.cfg"):
    print('does exist')
else:
    print('does not exist')
# Out:
# does exist
